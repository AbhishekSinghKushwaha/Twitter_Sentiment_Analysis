# %%
import tweepy as tw
import pandas as pd

# %%
consumer_key = 'oLnXfvqGCuakFw2LO3cQRzPCj'
consumer_secret = 'rgDfD2EBkCsSYcxiQzGmP3PdS3R1LKmrjH7CnU2SXX8MLf54UQ'

access_token = '824272736629456896-gML4XMgStlwkqcOO3IBgQ1o1UUcUUIx'
access_token_secret = 'Y1p48hk8JXe1OS9Zcf6ds7NG6G0y4ZHhHQNQHocX6SjOV'

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api = tw.API(auth)

# %%
search_words = "bitcoin"
date_since = "2020-06-14"

# %%
# Filtering Retweets
new_search = search_words + " -filter:retweets"
new_search
# Out:
# 'bitcoin -filter:retweets'

# %%
tweets = tw.Cursor(api.search, 
                           q=new_search,
                           lang="en",
                           since=date_since).items(100)

users_locs = [[tweet.user.screen_name, tweet.user.location, tweet.text] for tweet in tweets]
users_locs
# Out:
# [['CryptoMichNL',
#   'Amsterdam, The Netherlands',
#   'The world is ending, #BITCOIN is $9,100. \n\nStill +150% since the crash in March and best performing asset since. \n\nRelax\n\n$BTC'],
#  ['finbold',
#   'UK',
#   'Bitcoin beats a retreat as crypto markets shed $15 billion. https://t.co/4bjsTRkkM3 #bitcoin #btc #crypto… https://t.co/gs220B7xIP'],
#  ['EarningTamilan',
#   'Chennai, India',
#   'BITCOIN CLOUD MINING TAMIL | Passive Income | Earn without work | Earningtamilan \n#YouTube #YouTubersReact #React\nhttps://t.co/tLrwovzX2l'],
#  ['shorteners_net',
#   '',
#   'Exeio has added new payment method; Bitcoin from 5$ minimal withdraw: https://t.co/hjwOemEAly'],
#  ['denverbitcoin',
#   'Denver, CO',
#   "We gonna see $7965 again.\n\nDon't. Miss. It.\n\n#bitcoin"],
#  ['News_1jl4',
#   'World',
#   "Polaris has a 'once-in-a-generation opportunity,' Jim Cramer.. \nCNBC - News - Noticia - Bitcoin - CryptoCurrency -… https://t.co/eor9lDjV5B"],
#  ['bitcoinincoins',
# ...

# %%
tweet_text = pd.DataFrame(data=users_locs, 
                    columns=['user', "location", "Tweets"])
tweet_text
# Out:
#                user                    location  \
# 0      CryptoMichNL  Amsterdam, The Netherlands
# 1           finbold                          UK
# 2    EarningTamilan              Chennai, India
# 3    shorteners_net
# 4     denverbitcoin                  Denver, CO
# ..              ...                         ...
# 95  cecilie96787818
# 96        CoqonutCC                    new york
# 97     CPOfficialtx
# 98        xtradebot               United States
# 99     VaraPrasadCA
#
#                                                Tweets
# 0   The world is ending, #BITCOIN is $9,100. \n\nS...
# 1   Bitcoin beats a retreat as crypto markets shed...
# 2   BITCOIN CLOUD MINING TAMIL | Passive Income | ...
# 3   Exeio has added new payment method; Bitcoin fr...
# 4   We gonna see $7965 again.\n\nDon't. Miss. It.\...
# ..                                                ...
# 95  @paxful Please whats going on i opened a new a...
# 96  CME Data Shows Institutional Investors Undeter...
# ...

# %%
from google.colab import files
tweet_text.to_csv('tweet_text.csv') 
files.download('tweet_text.csv')

# %%
tweet_text.to_csv('C:\\Users\\abhi1\\Desktop\\NLP\\tweet_text1.csv')
